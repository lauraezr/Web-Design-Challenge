# %%
import pandas as pd

# %%
a = pd.read_csv("assets/city_data.csv")
a
# Out:
#      Unnamed: 0          City Country        Date  Humidity  Cloudiness  \
# 0             0  St. George's      GD  1626042307        89          75
# 1             1       Pangody      RU  1626042308        66          71
# 2             2  Teyateyaneng      LS  1626042308        38           1
# 3             3       Ushuaia      AR  1626042224        86          40
# 4             4        Atuona      PF  1626042109        80          46
# ..          ...           ...     ...         ...       ...         ...
# 553         553     Mahajanga      MG  1626042529        56          20
# 554         554        Luanda      AO  1626042449        94          75
# 555         555       Emerald      AU  1626042530        48          40
# 556         556       Tétouan      MA  1626042530        88          75
# 557         557     Cartagena      CO  1626042461        79          40
#
#          Lat      Long   Temp  WindSpeed
# 0    12.0564  -61.7485  78.48      17.27
# ...

# %%
output = a.to_html("output.html")
